# %%
from platform import python_version
import sklearn
import pandas
import tensorflow as tf

print("Python version: " +python_version())
print("sklearn version: " +sklearn.__version__)
print("pandas version: " +pandas.__version__)
print("tensorflow version: " +tf.__version__)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from __future__ import print_function
from tensorflow.python import _pywrap_util_port
import tensorflow
# Print version, and check whether is intel-optimized
print("tensorflow version: " +tensorflow.__version__)
print(_pywrap_util_port.IsMklEnabled())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sh 
conda list
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sh
apt-get update 
apt-get -y --force-yes install git
mkdir -p /home/intel/
cd /home/intel
git clone https://github.com/IntelPython/scikit-learn_bench.git 
cd /home/intel/scikit-learn_bench
git reset --hard  8c9e5284d65a5cd950
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sh
cd /home/intel/scikit-learn_bench
export USE_DAAL4PY_SKLEARN=YES
sed -i.bak 's/params.n_jobs/1/' sklearn_bench/log_reg.py
python runner.py --configs configs/skl_config.json  --verbose INFO |tee -a /dbfs/FileStore/skl_bench_res/benchmark_sklearn.txt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sh 
cat  /dbfs/FileStore/skl_bench_res/benchmark_sklearn.txt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
