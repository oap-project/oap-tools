# %%
from platform import python_version
import sklearn
import pandas
import tensorflow as tf

print("Python version: " +python_version())
print("sklearn version: " +sklearn.__version__)
print("pandas version: " +pandas.__version__)
print("tensorflow version: " +tf.__version__)
# Out:
# Python version: 3.9.5
# sklearn version: 0.24.2
# pandas version: 1.3.4
# tensorflow version: 2.8.0

# %%
# %sh
apt-get update 
apt-get -y --force-yes install git
mkdir -p /home/intel/
cd /home/intel
git clone https://github.com/IntelPython/scikit-learn_bench.git 
cd /home/intel/scikit-learn_bench
git reset --hard  7e0fc7f06b767d9090d766ce8a9202a292b7dc91
# Out:
# Hit:1 https://repos.azul.com/zulu/deb stable InRelease
# Hit:2 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# git is already the newest version (1:2.25.1-1ubuntu3.4).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# W: --force-yes is deprecated, use one of the options starting with --allow instead.
# Cloning into 'scikit-learn_bench'...
# HEAD is now at 8c9e528 Update copyright for 2021 year (#47)

# %%
# %sh
cd /home/intel/scikit-learn_bench/configs/
wget https://raw.githubusercontent.com/oap-project/oap-tools/master/integrations/ml/databricks/benchmark/skl_config_databricks.json
# Out:
# --2022-06-22 11:28:54--  https://raw.githubusercontent.com/oap-project/oap-tools/master/integrations/ml/databricks/benchmark/skl_config_databricks.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12573 (12K) [text/plain]
# Saving to: ‘skl_config_databricks.json’
#
#      0K .......... ..                                         100% 59.6M=0s
#
# 2022-06-22 11:28:54 (59.6 MB/s) - ‘skl_config_databricks.json’ saved [12573/12573]
#
# README.md
# config_example.json
# cuml_config.json
# lgbm_mb_cpu_config.json
# skl_config.json
# skl_config_databricks.json
# testing
# xgb_cpu_config.json
# xgb_gpu_config.json
# xgb_mb_cpu_config.json

# %%
# %sh
cd /home/intel/scikit-learn_bench
export USE_DAAL4PY_SKLEARN=YES
sed -i.bak 's/params.n_jobs/1/' sklearn_bench/log_reg.py
python runner.py --configs /dbfs/FileStore/skl_config_databricks.json  --verbose INFO |tee -a /dbfs/FileStore/sklearn_bench_log.txt
# Out:
# INFO: Config: /dbfs/FileStore/skl_post_config.json
# tee: /dbfs/FileStore/skl_bench_res/stock_sklearn.txt: Operation not supported
# INFO: kmeans algorithm: 1 case(s), 1 dataset(s)
#
# INFO: python sklearn_bench/kmeans.py --arch 0621-131916-grcesc2u-10-139-64-4 --data-format pandas --data-order F --dtype float64 --time-method box_filter --time-limit 50 --n-clusters 1000 --maxiter 50 --tol 0.0 --file-X-train data/synthetic-blobs-1000-X-train-1000000x20.npy --dataset-name synthetic_blobs
# [
#     {
#         "library": "sklearn",
#         "algorithm": "kmeans",
#         "stage": "training",
#         "input_data": {
#             "data_format": "pandas",
#             "data_order": "F",
#             "data_type": "float64",
#             "dataset_name": "synthetic_blobs",
#             "rows": 1000000,
#             "columns": 20,
#             "n_clusters": 1000
#         },
#         "algorithm_parameters": {
#             "algorithm": "auto",
#             "copy_x": true,
# ...

# %%
# %sh 
cat  /dbfs/FileStore/sklearn_bench_log.txt
# Out:
# INFO: Config: /dbfs/FileStore/skl_post_config.json
# INFO: kmeans algorithm: 1 case(s), 1 dataset(s)
#
# INFO: python sklearn_bench/kmeans.py --arch 0621-131009-b9ah2jcs-10-139-64-6 --data-format pandas --data-order F --dtype float64 --time-method box_filter --time-limit 50 --n-clusters 1000 --maxiter 50 --tol 0.0 --file-X-train data/synthetic-blobs-1000-X-train-1000000x20.npy --dataset-name synthetic_blobs
# [
#     {
#         "library": "sklearn",
#         "algorithm": "kmeans",
#         "stage": "training",
#         "input_data": {
#             "data_format": "pandas",
#             "data_order": "F",
#             "data_type": "float64",
#             "dataset_name": "synthetic_blobs",
#             "rows": 1000000,
#             "columns": 20,
#             "n_clusters": 1000
#         },
#         "algorithm_parameters": {
#             "algorithm": "auto",
#             "copy_x": true,
#             "init": "random",
#             "max_iter": 50,
# ...
