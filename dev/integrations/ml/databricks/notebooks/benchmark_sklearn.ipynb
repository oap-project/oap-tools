# %%
from platform import python_version
import sklearn
import pandas
import tensorflow as tf

print("Python version: " +python_version())
print("sklearn version: " +sklearn.__version__)
print("pandas version: " +pandas.__version__)
print("tensorflow version: " +tf.__version__)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python version: 3.7.9
# sklearn version: 0.23.2
# pandas version: 1.2.3
# tensorflow version: 2.3.0
# </div>

# %%
from __future__ import print_function
from tensorflow.python import _pywrap_util_port
import tensorflow
# Print version, and check whether is intel-optimized
print("tensorflow version: " +tensorflow.__version__)
print(_pywrap_util_port.IsMklEnabled())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">tensorflow version: 2.3.0
# True
# </div>

# %%
# %sh 
conda list
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"># packages in environment at /databricks/conda/envs/databricks-ml:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# absl-py                   0.9.0                    py37_0
# asn1crypto                1.3.0                    py37_1
# astor                     0.8.0                    py37_0
# astunparse                1.6.3                    pypi_0    pypi
# azure-core                1.9.0                    pypi_0    pypi
# azure-storage-blob        12.6.0                   pypi_0    pypi
# backcall                  0.1.0                    py37_0
# backports                 1.0                pyhd3eb1b0_2
# bcrypt                    3.2.0            py37h7b6447c_0
# blas                      1.0                         mkl
# blinker                   1.4                      py37_0
# boto3                     1.12.0                     py_0
# botocore                  1.15.0                     py_0
# bzip2                     1.0.8                h88c068d_5    intel
# c-ares                    1.17.1               h27cfd23_0
# ca-certificates           2021.1.19            h06a4308_1
# cachetools                4.1.1                      py_0
# certifi                   2020.6.20        py37hefe589e_1    intel
# cffi                      1.14.3           py37h698c159_1    intel
# chardet                   3.0.4           py37h06a4308_1003
# click                     7.0                      py37_0
# cloudpickle               1.4.1                      py_0
# common_cmplr_lib_rt       2021.1.2              intel_266    intel
# common_cmplr_lic_rt       2021.1.2              intel_266    intel
# configparser              3.7.4                    py37_0
# cpuonly                   1.0                           0    pytorch
# cryptography              2.8              py37h1ba5d50_0
# cycler                    0.10.0                   py37_0
# cython                    0.29.15          py37he6710b0_0
# daal                      2021.1.1               intel_79    intel
# daal4py                   2021.1           py37hdeddd62_3    intel
# dal                       2021.1.1               intel_79    intel
# databricks-cli            0.14.0                   pypi_0    pypi
# decorator                 4.4.1                      py_0
# dill                      0.3.1.1                  py37_1
# diskcache                 5.1.0                    pypi_0    pypi
# docker                    4.4.0                    pypi_0    pypi
# docutils                  0.15.2                   py37_0
# dpcpp_cpp_rt              2021.1.2              intel_266    intel
# entrypoints               0.3                      py37_0
# flask                     1.1.1                      py_1
# fortran_rt                2021.1.2              intel_266    intel
# freetype                  2.9.1                h8a8886c_1
# future                    0.18.2                   py37_1
# gast                      0.3.3                      py_0
# gitdb                     4.0.5                      py_0
# gitpython                 3.1.0                      py_0
# google-auth               1.11.2                     py_0
# google-auth-oauthlib      0.4.1                      py_2
# google-pasta              0.2.0                      py_0
# gorilla                   0.3.0                    pypi_0    pypi
# grpcio                    1.27.2           py37hf8bcb03_0
# gunicorn                  20.0.4                   py37_0
# h5py                      2.10.0           py37h7918eee_0
# hdf5                      1.10.4               hb1b8bf9_0
# horovod                   0.20.3                   pypi_0    pypi
# icc_rt                    2021.1.2              intel_266    intel
# icu                       58.2                 he6710b0_3
# idna                      2.8                      py37_0
# impi_rt                   2021.1.1               intel_76    intel
# intel-openmp              2021.1.2              intel_266    intel
# intel-tensorflow          2.3.0                    pypi_0    pypi
# intelpython               2021.1.1                      1    intel
# ipykernel                 5.3.4            py37h5ca1d4c_0
# ipython                   7.12.0           py37h5ca1d4c_0
# ipython_genutils          0.2.0              pyhd3eb1b0_1
# isodate                   0.6.0                      py_1
# itsdangerous              1.1.0                    py37_0
# jedi                      0.17.2                   py37_0
# jinja2                    2.11.1                     py_0
# jmespath                  0.10.0                     py_0
# joblib                    0.14.1                     py_0
# joblibspark               0.3.0                    pypi_0    pypi
# jpeg                      9b                   h024ee3a_2
# jupyter_client            5.3.4                    py37_0
# jupyter_core              4.6.1                    py37_0
# keras-preprocessing       1.1.2                    pypi_0    pypi
# kiwisolver                1.1.0            py37he6710b0_0
# koalas                    1.4.0                    pypi_0    pypi
# krb5                      1.16.4               h173b8e3_0
# ld_impl_linux-64          2.33.1               h53a641e_7
# libedit                   3.1.20181209         hc058e9b_0
# libffi                    3.3                 h07ac4c1_13    intel
# libgcc-ng                 9.1.0                hdf63c60_0
# libgfortran-ng            7.3.0                hdf63c60_0
# libpng                    1.6.37               hbc83047_0
# libpq                     11.2                 h20c2e04_0
# libprotobuf               3.11.4               hd408876_0
# libsodium                 1.0.16               h1bed415_0
# libstdcxx-ng              9.1.0                hdf63c60_0
# libtiff                   4.1.0                h2733197_0
# libuv                     1.40.0               h7b6447c_0
# lightgbm                  2.3.0            py37he6710b0_0
# lz4-c                     1.8.1.2              h14c3975_0
# mako                      1.1.2                      py_0
# markdown                  3.1.1                    py37_0
# markupsafe                1.1.1            py37h14c3975_1
# matplotlib-base           3.1.3            py37hef1b27d_0
# mkl                       2021.1.1               intel_52    intel
# mkl-service               2.3.0            py37hfc5565f_6    intel
# mkl_fft                   1.2.0            py37h3aece79_1    intel
# mkl_random                1.2.0            py37h0107b67_1    intel
# mkl_umath                 0.1.0            py37hb46b53c_0    intel
# mleap                     0.16.1                   pypi_0    pypi
# mlflow                    1.12.1                   pypi_0    pypi
# msrest                    0.6.19                   pypi_0    pypi
# ncurses                   6.2                  he6710b0_1
# networkx                  2.4                        py_1
# ninja                     1.10.2           py37hff7bd54_0
# nltk                      3.4.5                    py37_0
# numpy                     1.18.5                   pypi_0    pypi
# oauthlib                  3.1.0                      py_0
# olefile                   0.46                     py37_0
# opencl_rt                 2021.1.2              intel_266    intel
# openssl                   1.1.1h               h14c3975_0    intel
# opt-einsum                3.3.0                    pypi_0    pypi
# packaging                 20.1                       py_0
# pandas                    1.2.3            py37ha9443f7_0
# paramiko                  2.7.1                      py_0
# parso                     0.7.0                      py_0
# patsy

# %%
# %sh
apt-get update 
apt-get -y --force-yes install git
mkdir -p /home/intel/
cd /home/intel
git clone https://github.com/IntelPython/scikit-learn_bench.git 
git reset  8c9e5284d65a5cd950
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://repos.azul.com/zulu/deb stable InRelease [3,191 B]
# Get:3 https://repos.azul.com/zulu/deb stable/main amd64 Packages [78.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic InRelease [242 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,045 kB]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [348 kB]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,402 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [24.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [186 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [11.3 MB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 Packages [1,344 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/restricted amd64 Packages [13.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,475 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,170 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [378 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [31.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [11.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [11.4 kB]
# Fetched 22.4 MB in 8s (2,674 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Suggested packages:
#   gettext-base git-daemon-run | git-daemon-sysvinit git-doc git-el git-email
#   git-gui gitk gitweb git-cvs git-mediawiki git-svn
# The following packages will be upgraded:
#   git
# 1 upgraded, 0 newly installed, 0 to remove and 56 not upgraded.
# Need to get 3,916 kB of archives.
# After this operation, 8,192 B of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git amd64 1:2.17.1-1ubuntu0.8 [3,916 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 3,916 kB in 3s (1,232 kB/s)
# (Reading database ...
# (Reading database ... 5%
# (Reading database ... 10%
# (Reading database ... 15%
# (Reading database ... 20%
# (Reading database ... 25%
# (Reading database ... 30%
# (Reading database ... 35%
# (Reading database ... 40%
# (Reading database ... 45%
# (Reading database ... 50%
# (Reading database ... 55%
# (Reading database ... 60%
# (Reading database ... 65%
# (Reading database ... 70%
# (Reading database ... 75%
# (Reading database ... 80%
# (Reading database ... 85%
# (Reading database ... 90%
# (Reading database ... 95%
# (Reading database ... 100%
# (Reading database ... 95857 files and directories currently installed.)
# Preparing to unpack .../git_1%3a2.17.1-1ubuntu0.8_amd64.deb ...
# Unpacking git (1:2.17.1-1ubuntu0.8) over (1:2.17.1-1ubuntu0.7) ...
# Setting up git (1:2.17.1-1ubuntu0.8) ...
# W: --force-yes is deprecated, use one of the options starting with --allow instead.
# Cloning into &#39;scikit-learn_bench&#39;...
# </div>

# %%
# %sh
cd /home/intel/scikit-learn_bench
export USE_DAAL4PY_SKLEARN=YES
sed -i.bak 's/params.n_jobs/1/' sklearn_bench/log_reg.py
python runner.py --configs configs/skl_config.json  --verbose INFO |tee -a /dbfs/FileStore/skl_bench_res/skl_bench_init_script.txt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO: Config: configs/skl_config.json
# INFO: kmeans algorithm: 1 case(s), 1 dataset(s)
#
# INFO: python sklearn_bench/kmeans.py --arch 0317-025359-cites481-10-139-64-4 --data-format pandas --data-order F --dtype float64 --time-method box_filter --time-limit 50 --n-clusters 1000 --maxiter 50 --tol 0.0 --file-X-train data/synthetic-blobs-1000-X-train-1000000x20.npy --dataset-name synthetic_blobs
# [
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;training&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 1000000,
#             &#34;columns&#34;: 20,
#             &#34;n_clusters&#34;: 1000
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;random&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 1000,
#             &#34;n_init&#34;: 1,
#             &#34;n_jobs&#34;: &#34;deprecated&#34;,
#             &#34;precompute_distances&#34;: &#34;deprecated&#34;,
#             &#34;random_state&#34;: null,
#             &#34;tol&#34;: 0.0,
#             &#34;verbose&#34;: 0
#         },
#         &#34;time[s]&#34;: 8.510202025666691,
#         &#34;davies_bouldin_score&#34;: 2.143728296757521
#     },
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;prediction&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 1000000,
#             &#34;columns&#34;: 20,
#             &#34;n_clusters&#34;: 1000
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;random&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 1000,
#             &#34;n_init&#34;: 1,
#             &#34;n_jobs&#34;: &#34;deprecated&#34;,
#             &#34;precompute_distances&#34;: &#34;deprecated&#34;,
#             &#34;random_state&#34;: null,
#             &#34;tol&#34;: 0.0,
#             &#34;verbose&#34;: 0
#         },
#         &#34;time[s]&#34;: 0.29972669193683776,
#         &#34;davies_bouldin_score&#34;: 2.143728296757521
#     }
# ]
#
# WARNING: Error in benchmark:
#
#
# INFO: kmeans algorithm: 1 case(s), 1 dataset(s)
#
# INFO: python sklearn_bench/kmeans.py --arch 0317-025359-cites481-10-139-64-4 --data-format pandas --data-order F --dtype float64 --time-method box_filter --time-limit 50 --n-clusters 5 --maxiter 50 --init k-means++ --tol 0.0 --file-X-train data/synthetic-blobs-5-X-train-10000000x50.npy --dataset-name synthetic_blobs
# [
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;training&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 10000000,
#             &#34;columns&#34;: 50,
#             &#34;n_clusters&#34;: 5
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;k-means++&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 5,
#             &#34;n_init&#34;: 1,
#             &#34;n_jobs&#34;: &#34;deprecated&#34;,
#             &#34;precompute_distances&#34;: &#34;deprecated&#34;,
#             &#34;random_state&#34;: null,
#             &#34;tol&#34;: 0.0,
#             &#34;verbose&#34;: 0
#         },
#         &#34;time[s]&#34;: 7.462584779666694,
#         &#34;davies_bouldin_score&#34;: 0.08354410412797438
#     },
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;prediction&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 10000000,
#             &#34;columns&#34;: 50,
#             &#34;n_clusters&#34;: 5
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;k-means++&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 5,
#             &#34;n_init&#34;: 1,
#             &#34;n_jobs&#34;: &#34;deprecated&#34;,
#             &#34;precompute_distances&#34;: &#34;deprecated&#34;,
#             &#34;random_state&#34;: null,
#             &#34;tol&#34;: 0.0,
#             &#34;verbose&#34;: 0
#         },
#         &#34;time[s]&#34;: 0.11511252762637184,
#         &#34;davies_bouldin_score&#34;: 0.08354410412797438
#     }
# ]
#
# WARNING: Error in benchmark:
#
#
# INFO: kmeans algorithm: 1 case(s), 1 dataset(s)
#
# INFO: python sklearn_bench/kmeans.py --arch 0317-025359-cites481-10-139-64-4 --data-format pandas --data-order F --dtype float64 --time-method box_filter --time-limit 50 --n-clusters 20 --maxiter 50 --tol 0.0 --file-X-train data/synthetic-blobs-20-X-train-3000000x50.npy --dataset-name synthetic_blobs
# [
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;training&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 3000000,
#             &#34;columns&#34;: 50,
#             &#34;n_clusters&#34;: 20
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;random&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 20,
#             &#34;n_init&#34;: 1,
#             &#34;n_jobs&#34;: &#34;deprecated&#34;,
#             &#34;precompute_distances&#34;: &#34;deprecated&#34;,
#             &#34;random_state&#34;: null,
#             &#34;tol&#34;: 0.0,
#             &#34;verbose&#34;: 0
#         },
#         &#34;time[s]&#34;: 3.190861202562523,
#         &#34;davies_bouldin_score&#34;: 4.602902714842953
#     },
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;prediction&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 3000000,
#             &#34;columns&#34;: 50,
#             &#34;n_clusters&#34;: 20
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;random&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 20,
#             &

# %%
# %sh 
cat  /dbfs/FileStore/skl_bench_res/skl_bench_init_script.txt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO: Config: configs/skl_config.json
# INFO: kmeans algorithm: 1 case(s), 1 dataset(s)
#
# INFO: python sklearn_bench/kmeans.py --arch 0317-025359-cites481-10-139-64-4 --data-format pandas --data-order F --dtype float64 --time-method box_filter --time-limit 50 --n-clusters 1000 --maxiter 50 --tol 0.0 --file-X-train data/synthetic-blobs-1000-X-train-1000000x20.npy --dataset-name synthetic_blobs
# [
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;training&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 1000000,
#             &#34;columns&#34;: 20,
#             &#34;n_clusters&#34;: 1000
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;random&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 1000,
#             &#34;n_init&#34;: 1,
#             &#34;n_jobs&#34;: &#34;deprecated&#34;,
#             &#34;precompute_distances&#34;: &#34;deprecated&#34;,
#             &#34;random_state&#34;: null,
#             &#34;tol&#34;: 0.0,
#             &#34;verbose&#34;: 0
#         },
#         &#34;time[s]&#34;: 8.510202025666691,
#         &#34;davies_bouldin_score&#34;: 2.143728296757521
#     },
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;prediction&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 1000000,
#             &#34;columns&#34;: 20,
#             &#34;n_clusters&#34;: 1000
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;random&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 1000,
#             &#34;n_init&#34;: 1,
#             &#34;n_jobs&#34;: &#34;deprecated&#34;,
#             &#34;precompute_distances&#34;: &#34;deprecated&#34;,
#             &#34;random_state&#34;: null,
#             &#34;tol&#34;: 0.0,
#             &#34;verbose&#34;: 0
#         },
#         &#34;time[s]&#34;: 0.29972669193683776,
#         &#34;davies_bouldin_score&#34;: 2.143728296757521
#     }
# ]
#
# WARNING: Error in benchmark:
#
#
# INFO: kmeans algorithm: 1 case(s), 1 dataset(s)
#
# INFO: python sklearn_bench/kmeans.py --arch 0317-025359-cites481-10-139-64-4 --data-format pandas --data-order F --dtype float64 --time-method box_filter --time-limit 50 --n-clusters 5 --maxiter 50 --init k-means++ --tol 0.0 --file-X-train data/synthetic-blobs-5-X-train-10000000x50.npy --dataset-name synthetic_blobs
# [
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;training&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 10000000,
#             &#34;columns&#34;: 50,
#             &#34;n_clusters&#34;: 5
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;k-means++&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 5,
#             &#34;n_init&#34;: 1,
#             &#34;n_jobs&#34;: &#34;deprecated&#34;,
#             &#34;precompute_distances&#34;: &#34;deprecated&#34;,
#             &#34;random_state&#34;: null,
#             &#34;tol&#34;: 0.0,
#             &#34;verbose&#34;: 0
#         },
#         &#34;time[s]&#34;: 7.462584779666694,
#         &#34;davies_bouldin_score&#34;: 0.08354410412797438
#     },
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;prediction&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 10000000,
#             &#34;columns&#34;: 50,
#             &#34;n_clusters&#34;: 5
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;k-means++&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 5,
#             &#34;n_init&#34;: 1,
#             &#34;n_jobs&#34;: &#34;deprecated&#34;,
#             &#34;precompute_distances&#34;: &#34;deprecated&#34;,
#             &#34;random_state&#34;: null,
#             &#34;tol&#34;: 0.0,
#             &#34;verbose&#34;: 0
#         },
#         &#34;time[s]&#34;: 0.11511252762637184,
#         &#34;davies_bouldin_score&#34;: 0.08354410412797438
#     }
# ]
#
# WARNING: Error in benchmark:
#
#
# INFO: kmeans algorithm: 1 case(s), 1 dataset(s)
#
# INFO: python sklearn_bench/kmeans.py --arch 0317-025359-cites481-10-139-64-4 --data-format pandas --data-order F --dtype float64 --time-method box_filter --time-limit 50 --n-clusters 20 --maxiter 50 --tol 0.0 --file-X-train data/synthetic-blobs-20-X-train-3000000x50.npy --dataset-name synthetic_blobs
# [
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;training&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 3000000,
#             &#34;columns&#34;: 50,
#             &#34;n_clusters&#34;: 20
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;random&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 20,
#             &#34;n_init&#34;: 1,
#             &#34;n_jobs&#34;: &#34;deprecated&#34;,
#             &#34;precompute_distances&#34;: &#34;deprecated&#34;,
#             &#34;random_state&#34;: null,
#             &#34;tol&#34;: 0.0,
#             &#34;verbose&#34;: 0
#         },
#         &#34;time[s]&#34;: 3.190861202562523,
#         &#34;davies_bouldin_score&#34;: 4.602902714842953
#     },
#     {
#         &#34;library&#34;: &#34;sklearn&#34;,
#         &#34;algorithm&#34;: &#34;kmeans&#34;,
#         &#34;stage&#34;: &#34;prediction&#34;,
#         &#34;input_data&#34;: {
#             &#34;data_format&#34;: &#34;pandas&#34;,
#             &#34;data_order&#34;: &#34;F&#34;,
#             &#34;data_type&#34;: &#34;float64&#34;,
#             &#34;dataset_name&#34;: &#34;synthetic_blobs&#34;,
#             &#34;rows&#34;: 3000000,
#             &#34;columns&#34;: 50,
#             &#34;n_clusters&#34;: 20
#         },
#         &#34;algorithm_parameters&#34;: {
#             &#34;algorithm&#34;: &#34;auto&#34;,
#             &#34;copy_x&#34;: true,
#             &#34;init&#34;: &#34;random&#34;,
#             &#34;max_iter&#34;: 50,
#             &#34;n_clusters&#34;: 20,
#             &
